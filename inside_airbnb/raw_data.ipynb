# %% [markdown]
# # Fist Pass Inside Airbnb Data

# %%
import pandas as pd

# %% [markdown]
# ## General Breakdown of Inside Airbnb Tables

# %% [markdown]
# ### Listings Tables

# %%
listings = pd.read_csv('data/Asheville/listings.csv')
print(listings.shape)
listings.head()
# Out:
# (2172, 74)
#        id                          listing_url       scrape_id last_scraped  \
# 0  108061  https://www.airbnb.com/rooms/108061  20201108173816   2020-11-08
# 1  155305  https://www.airbnb.com/rooms/155305  20201108173816   2020-11-08
# 2  156926  https://www.airbnb.com/rooms/156926  20201108173816   2020-11-08
# 3  160594  https://www.airbnb.com/rooms/160594  20201108173816   2020-11-08
# 4  209068  https://www.airbnb.com/rooms/209068  20201108173816   2020-11-08
#
#                                                 name  \
# 0  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                 Cottage! BonPaul + Sharky's Hostel
# 2             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 3                                Historic Grove Park
# 4                                    Terrace Cottage
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental in...
# 1  <b>The space</b><br />Private cottage located ...
# ...

# %%
# How to Find a Better Taret Variable
listings['price'][:5]
# Out:
# 0     $82.00
# 1     $92.00
# 2     $30.00
# 3    $125.00
# 4    $134.00
# Name: price, dtype: object

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2172 entries, 0 to 2171
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2172 non-null   int64
#  1   listing_url                                   2172 non-null   object
#  2   scrape_id                                     2172 non-null   int64
#  3   last_scraped                                  2172 non-null   object
#  4   name                                          2172 non-null   object
#  5   description                                   2167 non-null   object
#  6   neighborhood_overview                         1760 non-null   object
#  7   picture_url                                   2172 non-null   object
#  8   host_id                                       2172 non-null   int64
# ...

# %% [markdown]
# ### Reviews Tables

# %%
reviews = pd.read_csv('data/Asheville/reviews.csv')
print(reviews.shape)
reviews.head()
# Out:
# (173892, 6)
#    listing_id       id        date  reviewer_id  reviewer_name  \
# 0      108061   553741  2011-09-21       822907  Pedro & Katie
# 1      108061   683278  2011-11-01       236064            Tim
# 2      108061   714889  2011-11-13      1382707          Shane
# 3      108061  1766157  2012-07-21       416731         Brenda
# 4      108061  2033065  2012-08-19      1858880        Lindsey
#
#                                             comments
# 0  Lisa is superb hostess, she will treat you lik...
# 1  This was a lovely little place walking distanc...
# 2  Lisa was very nice to work with.  However, we ...
# 3  I feel very lucky to have found this beautiful...
# 4  Great roomy little apartment, beautiful privat...

# %%
# Foreign Key?
reviews['id'][:5]
# Out:
# 0     553741
# 1     683278
# 2     714889
# 3    1766157
# 4    2033065
# Name: id, dtype: int64

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173892 entries, 0 to 173891
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     173892 non-null  int64
#  1   id             173892 non-null  int64
#  2   date           173892 non-null  object
#  3   reviewer_id    173892 non-null  int64
#  4   reviewer_name  173892 non-null  object
#  5   comments       173838 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 8.0+ MB

# %% [markdown]
# ## Each City

# %%
# Ashville

ashville_lst = pd.read_csv('data/Asheville/listings.csv')
ashville_rvs = pd.read_csv('data/Asheville/reviews.csv')

print('Ashville Listings')
print(ashville_lst.shape)
print('\nAshville Reviews')
print(ashville_rvs.shape)
ashville_rvs.head(3)
# Out:
# Ashville Listings
# (2172, 74)
#
# Ashville Reviews
# (173892, 6)
#    listing_id      id        date  reviewer_id  reviewer_name  \
# 0      108061  553741  2011-09-21       822907  Pedro & Katie
# 1      108061  683278  2011-11-01       236064            Tim
# 2      108061  714889  2011-11-13      1382707          Shane
#
#                                             comments
# 0  Lisa is superb hostess, she will treat you lik...
# 1  This was a lovely little place walking distanc...
# 2  Lisa was very nice to work with.  However, we ...

# %%
# Austin

austin_lst = pd.read_csv('data/Austin/listings.csv')
austin_rvs = pd.read_csv('data/Austin/reviews.csv')

print('Austin Listings')
print(austin_lst.shape)
print('\nAustin Reviews')
print(austin_rvs.shape)
austin_rvs.head(3)
# Out:
# Austin Listings
# (10450, 74)
#
# Austin Reviews
# (321484, 6)
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0        2265     963  2009-03-17         7538         Niall
# 1        2265    1057  2009-03-22        10029       Michael
# 2        2265  200418  2011-03-16        61677        Gustaf
#
#                                             comments
# 0  I stayed here during SXSW and had a really ple...
# 1  Great place, close enough to everything downto...
# 2  We had a great time in Austin staying at Paddy...

# %%
# Broward County

broward_lst = pd.read_csv('data/Broward_County/listings.csv')
broward_rvs = pd.read_csv('data/Broward_County/reviews.csv')

print('Broward County Listings')
print(broward_lst.shape)
print('\nBroward County Reviews')
print(broward_rvs.shape)
broward_rvs.head(3)
# Out:
# Broward County Listings
# (10071, 74)
#
# Broward County Reviews
# (215455, 6)
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       57818  3247141  2013-01-03      4203034        Gaurav
# 1       57818  3402974  2013-01-23       252741  Karen & Adam
# 2       57818  3427358  2013-01-28      4539300          Seth
#
#                                             comments
# 0  It was the first trip to Miami for most of us ...
# 1  Wonderful!  Janice was a pleasure to work with...
# 2  Janice was a wonderful host.  Very accommodati...

# %%
# Clark County

clark_lst = pd.read_csv('data/Clark_County/listings.csv')
clark_rvs = pd.read_csv('data/Clark_County/reviews.csv')

print('Clark County Listings')
print(clark_lst.shape)
print('\nClark County Reviews')
print(clark_rvs.shape)
clark_rvs.head(3)
# Out:
# Clark County Listings
# (9156, 74)
#
# Clark County Reviews
# (267537, 6)
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       31388    176556  2011-01-31       339758         Chris
# 1       31388   3884854  2013-03-25      1644721          Matt
# 2       31388  10758518  2014-03-06      7130425            Kt
#
#                                             comments
# 0  Great place -- very clean, spacious and comfor...
# 1  The unit was great! Check in was smooth and th...
# 2  Great experience!  Loved the room and the loca...

# %%
# Nashville

nashville_lst = pd.read_csv('data/Nashville/listings.csv')
nashville_rvs = pd.read_csv('data/Nashville/reviews.csv')

print('Nashville Listings')
print(nashville_lst.shape)
print('\nNashville Reviews')
print(nashville_rvs.shape)
nashville_rvs.head(3)
# Out:
# Nashville Listings
# (5945, 74)
#
# Nashville Reviews
# (322322, 6)
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        6422  1927  2009-04-30        14100       Melissa
# 1        6422  3867  2009-06-11        17413        Raquel
# 2        6422  4159  2009-06-17        20253        Ulrike
#
#                                             comments
# 0  I can't say enough about how wonderful it was ...
# 1  Michelle and Collier's home is wonderful! They...
# 2  I spent one night at Michele's home and felt j...

# %%
# Ottawa

ottawa_lst = pd.read_csv('data/Ottawa/listings.csv')
ottawa_rvs = pd.read_csv('data/Ottawa/reviews.csv')

print('Ottawa Listings')
print(ottawa_lst.shape)
print('\nOttawa Reviews')
print(ottawa_rvs.shape)
ottawa_rvs.head(3)
# Out:
# Ottawa Listings
# (2669, 74)
#
# Ottawa Reviews
# (100764, 6)
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       36642   63694  2010-07-11       126491        Robert
# 1       36642   92464  2010-09-07       204008       Eduardo
# 2       36642  100164  2010-09-19       164372          Asha
#
#                                             comments
# 0  I gave Donna 4 stars only because she is new t...
# 1  Donna is a nice and pleasant person. We enjoye...
# 2  Our trip was too short in Ottawa, we really wi...

# %%
# Salem, OR

salem_lst = pd.read_csv('data/Salem_OR/listings.csv')
salem_rvs = pd.read_csv('data/Salem_OR/reviews.csv')

print('Salem Listings')
print(salem_lst.shape)
print('\nSalem Reviews')
print(salem_rvs.shape)
salem_rvs.head(3)
# Out:
# Salem Listings
# (157, 74)
#
# Salem Reviews
# (7994, 6)
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     1159564   6502395  2013-08-14      7776893         Aaron
# 1     1159564   6928737  2013-08-30       143866          Inge
# 2     2894591  14254207  2014-06-15       315272        Elaine
#
#                                             comments
# 0  Roberta was a great hostess who provided all t...
# 1  I had a very nice stay with Roberta. The room ...
# 2  Sue was a very welcoming and went to great len...

# %%
salem_rvs['date']
# Out:
# 0       2013-08-14
# 1       2013-08-30
# 2       2014-06-15
# 3       2014-06-16
# 4       2014-06-30
#            ...
# 7989    2020-10-04
# 7990    2020-10-04
# 7991    2020-10-07
# 7992    2020-10-09
# 7993    2020-10-18
# Name: date, Length: 7994, dtype: object
